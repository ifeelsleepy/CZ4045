# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
def get_data(filename):
    with open(filename, 'r') as f:
        data = f.read()
    data_list =data.split(',')
    ppl_float=[]
    for i in range(len(data_list)-1):
        ppl_str = data_list[i][-9:].strip()
        ppl_float.append(float(ppl_str))
    return ppl_float

# %%
normal_ppl = get_data('train_data_normal.txt')
sgd_ppl = get_data('train_data_sgd.txt')
tied_ppl = get_data('train_data_tied.txt')
tied_ppl_sgd = get_data('train_data_tied_sgd.txt')

# %%
plt.plot(normal_ppl, label='Original Perplexity')
plt.plot(tied_ppl, label='Perplexity after sharing weights')
plt.legend()

# %%
plt.plot(sgd_ppl, label='normal_ppl')
plt.plot(tied_ppl_sgd, label='normal_ppl')
